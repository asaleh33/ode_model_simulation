# %% [markdown]
# ## Importing ODE library

# %%
from odeLIB import *

# %% [markdown]
# ## Generating simulation input file

# %%
# !echo "#================ METHOD STIFF ================ \
\rSTARTTIME 0 \
\rSTOPTIME 2000 \
\rDT 0.02 \
\rDTMAX 100 \
\rTOLERANCE 1e-6 \
\r#================ Parameter List ================ \
\r#================ Vesicle Shape Variables (assumes spherical compartment ================ \
\rR 0.34\
\r#================ Surface Potentials in mV ================ \
\rpsi_in 0 \
\rpsi_out -50 \
\rinitpsi_total 0 \
\r#================ Standard Constants ================ \
\rmole 6.02e23 \
\rRTF 25.69 \
\rF 96485 \
\rcap_0 1e-6 \
\r#================ Cytosolic Concentrations ================ \
\rpHbulk 7.2 \
\rKbulk 0.145 \
\rClbulk 0.01 \
\rNabulk 0.01 \
\r#================ Luminal Concentrations ================ \
\rinitpH 7.4 \
\rinitk 0.005 \
\rinitcl 0.11 \
\rinitna 0.145 \
\rinitH 0.00 \
\r#================ Kinetic Parameters ================ \
\r#==================================================== \
\rP 6.0e-5           # H+ permeability \
\rPcl 0              # Cl+ permeability \
\rPk 0               # K+ permeability \
\rPna 0              # Na+ permeability \
\rPw 0               # Water permeability \
\rN_VATP 300         # Number of V-ATPases \
\rN_CLC 5000         # Number of ClC-7 antiporters \
\rCLC_Cl 2           # ClC-7 Cl- Stoichiometry \
\rCLC_H 1            # ClC-7 H+ Stoichiometry \
\rOc 0.291           # Cytoplasmic Osmolarity [M] \
\roh 0.73            # H+ Osmotic coefficient \
\rok 0.73            # K+ Osmotic coefficient \
\rona 0.73           # Na+ Osmotic coefficient \
\rocl 0.73           # Cl- Osmotic coefficient \
\r#================ buffering capacity [mM/pH unit] ================ \
\r#================================================================= \
\rbeta 0.04" >> tmpfile && mv tmpfile input.txt

# %% [markdown]
# ## Running ODEMODEL simulation

# %%
if __name__ == "__main__":
    main()
# Out:
# inputfile: {'STARTTIME': 0.0, 'STOPTIME': 2000.0, 'DT': 0.02, 'DTMAX': 100.0, 'TOLERANCE': 1e-06, 'R': 0.34, 'psi_in': 0.0, 'psi_out': -50.0, 'initpsi_total': 0.0, 'mole': 6.02e+23, 'RTF': 25.69, 'F': 96485.0, 'cap_0': 1e-06, 'pHbulk': 7.2, 'Kbulk': 0.145, 'Clbulk': 0.01, 'Nabulk': 0.01, 'initpH': 7.4, 'initk': 0.005, 'initcl': 0.11, 'initna': 0.145, 'initH': 0.0, 'P': 6e-05, 'Pcl': 0.0, 'Pk': 0.0, 'Pna': 0.0, 'Pw': 0.0, 'N_VATP': 300.0, 'N_CLC': 5000.0, 'CLC_Cl': 2.0, 'CLC_H': 1.0, 'Oc': 0.291, 'oh': 0.73, 'ok': 0.73, 'ona': 0.73, 'ocl': 0.73, 'beta': 0.04}
#
# initial conditions: 7.4 10902209.84003497 495554.9927288622 14371094.789137004 0.0 1.6463621020892433e-16
